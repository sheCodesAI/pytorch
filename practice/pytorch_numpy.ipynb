# %% [markdown]
# <a href="https://colab.research.google.com/github/sheCodesAI/pytorch/blob/main/pytorch_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
torch.cuda.get_device_name(0)
# Out:
# 'Tesla T4'

# %%
torch.cuda.device(0)

# %% [markdown]
# ##Tensors

# %%
import numpy as np

arr = np.array([[1,2,3],[4,5,6]])
arr
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
tensor = torch.Tensor([[1,2,3], [4,5,6]])
tensor
# Out:
# tensor([[1., 2., 3.],
#         [4., 5., 6.]])

# %%
arr * 5  # numpy
# Out:
# array([[ 5, 10, 15],
#        [20, 25, 30]])

# %%
tensor * 5
# Out:
# tensor([[ 5., 10., 15.],
#         [20., 25., 30.]])

# %%
arr.sum()
# Out:
# np.int64(21)

# %%
tensor.sum()
# Out:
# tensor(21.)

# %%
tensor = torch.from_numpy(arr)
tensor
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
np.ones((2,4))
# Out:
# array([[1., 1., 1., 1.],
#        [1., 1., 1., 1.]])

# %%
torch.ones((2,2))
# Out:
# tensor([[1., 1.],
#         [1., 1.]])

# %%
np.random.random((2,4))
# Out:
# array([[0.02558637, 0.9493029 , 0.61031616, 0.07164814],
#        [0.95841679, 0.93849136, 0.34299174, 0.92696958]])

# %%
torch.rand((2,4))
# Out:
# tensor([[0.1158, 0.8205, 0.0802, 0.2850],
#         [0.5568, 0.1000, 0.5744, 0.6242]])

# %%
arr.shape
# Out:
# (2, 3)

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr.size
# Out:
# 6

# %%
arr.device
# Out:
# 'cpu'

# %%
tensor.device
# Out:
# device(type='cpu')

# %% [markdown]
# ##arr.to_device('cuda')
# bcz numpy doesn't support gpu

# %%
tensor = tensor.to('cuda')

# %%
tensor.device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# ##convert gpu to cpu again

# %%
tensor.cpu().numpy()
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
tensor.device
# Out:
# device(type='cuda', index=0)
